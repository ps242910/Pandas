# %%
import pandas as pd

# %%
pd.read_excel("P:\powerbi\Copy of Sample - Superstore powerbi1.xlsx",sheet_name='People')
# Out:
# C:\Users\ps242\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
file1_customer_churn=pd.read_csv(r"P:\powerbi\projects by Vinay Sir\customer churn analysis\data.csv\data.csv", encoding='unicode_escape')

# %%
file1_customer_churn
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
file2 =file1_customer_churn.head(10)

# %%
file2
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %%
type(file2)
# Out:
# pandas.core.frame.DataFrame

# %%
pwd()
# Out:
# 'C:\\Users\\ps242'

# %%
import os

# %%
os.chdir('P:\\python')

# %%
file2.to_csv("customer_churn_10_records.csv",index=False)

# %%
pd.read_csv("customer_churn_10_records.csv",header=None,names=["a","b","c","d","e","f","g","h","i"],skiprows=[0,4,6], na_values=[6])
# Out:
#         a       b                                   c     d               e  \
# 0  536365  85123A  WHITE HANGING HEART T-LIGHT HOLDER   NaN  12/1/2010 8:26
# 1  536365   71053                 WHITE METAL LANTERN   NaN  12/1/2010 8:26
# 2  536365  84406B      CREAM CUPID HEARTS COAT HANGER   8.0  12/1/2010 8:26
# 3  536365  84029E      RED WOOLLY HOTTIE WHITE HEART.   NaN  12/1/2010 8:26
# 4  536365   21730   GLASS STAR FROSTED T-LIGHT HOLDER   NaN  12/1/2010 8:26
# 5  536366   22633              HAND WARMER UNION JACK   NaN  12/1/2010 8:28
# 6  536366   22632           HAND WARMER RED POLKA DOT   NaN  12/1/2010 8:28
# 7  536367   84879       ASSORTED COLOUR BIRD ORNAMENT  32.0  12/1/2010 8:34
#
#       f        g               h   i
# 0  2.55  17850.0  United Kingdom NaN
# 1  3.39  17850.0  United Kingdom NaN
# 2  2.75  17850.0  United Kingdom NaN
# 3  3.39  17850.0  United Kingdom NaN
# 4  4.25  17850.0  United Kingdom NaN
# 5  1.85  17850.0  United Kingdom NaN
# ...

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
os.chdir('C:\\Users\\ps242')

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
file2.describe()
# Out:
#         Quantity  UnitPrice   CustomerID
# count  10.000000  10.000000     10.00000
# mean    8.400000   3.276000  17369.70000
# std     8.422193   1.748194   1518.84196
# min     2.000000   1.690000  13047.00000
# 25%     6.000000   2.025000  17850.00000
# 50%     6.000000   3.070000  17850.00000
# 75%     6.000000   3.390000  17850.00000
# max    32.000000   7.650000  17850.00000

# %%
file2
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %%
file2.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
a =[1,2,45,"78","78"]

# %%
def retuen_arr(a):
       if(type(a)==int):
            return a

# %%
list(filter(lambda p:type(p)==int,a))
# Out:
# [1, 2, 45]

# %%
file2=pd.read_excel("P:\powerbi\date_time_practice_excelsheet1.xlsx")

# %%
file2
# Out:
#    Unnamed: 0 Unnamed: 1           Unnamed: 2           Unnamed: 3
# 0         NaN        NaN                  NaN                  NaN
# 1         NaN       name                date1                date2
# 2         NaN      kirti  2022-11-12 00:00:00  2022-01-13 00:00:00
# 3         NaN    shuruti  2023-12-01 00:00:00  2023-12-13 00:00:00
# 4         NaN      kriya  1998-07-13 00:00:00  1998-05-07 00:00:00
# 5         NaN      priya  1999-06-27 00:00:00  2023-10-04 00:00:00
# 6         NaN     urmila  1976-04-26 00:00:00  1976-07-23 00:00:00
# 7         NaN  brajendra  1970-01-01 00:00:00  1976-01-01 00:00:00
# 8         NaN      jyoti  1993-07-05 00:00:00  1993-10-05 00:00:00

# %%
df1=pd.read_html('https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool')

# %%
df1
# Out:
# [       Season   Age                                     Tm  \
#  0     2008-09  19.0  Did Not Play (other pro league—Spain)
#  1     2009-10  20.0                                    OKC
#  2     2010-11  21.0                                    OKC
#  3     2011-12  22.0                                    OKC
#  4     2012-13  23.0                                    OKC
#  5     2013-14  24.0                                    OKC
#  6     2014-15  25.0                                    OKC
#  7     2015-16  26.0                                    OKC
#  8     2016-17  27.0                                    TOT
#  9     2016-17  27.0                                    ORL
#  10    2016-17  27.0                                    TOR
#  11    2017-18  28.0                                    TOR
#  12    2018-19  29.0                                    TOR
#  13    2019-20  30.0                                    TOR
#  14    2020-21  31.0                                    LAC
# ...

# %%
type(df1)
# Out:
# list

# %%
for i in df1:
    print(i)
# Out:
#        Season   Age                                     Tm  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
df1[6]
# Out:
#        Season   Age   Tm   Lg  Pos      G      MP   PER    TS%   3PAr  ...  \
# 0     2009-10  20.0  OKC  NBA   PF    6.0   153.0  15.3  0.596  0.000  ...
# 1     2010-11  21.0  OKC  NBA   PF   17.0   490.0  15.2  0.514  0.007  ...
# 2     2011-12  22.0  OKC  NBA   PF   20.0   569.0  18.9  0.558  0.025  ...
# 3     2012-13  23.0  OKC  NBA   PF   11.0   366.0  17.1  0.484  0.067  ...
# 4     2013-14  24.0  OKC  NBA   PF   17.0   581.0  16.6  0.633  0.088  ...
# 5     2015-16  26.0  OKC  NBA   PF   18.0   602.0  15.3  0.629  0.423  ...
# 6     2016-17  27.0  TOR  NBA   PF   10.0   307.0  14.4  0.527  0.292  ...
# 7     2017-18  28.0  TOR  NBA   PF   10.0   260.0  10.9  0.533  0.333  ...
# 8     2018-19  29.0  TOR  NBA    C   24.0   500.0  15.1  0.532  0.197  ...
# 9     2019-20  30.0  TOR  NBA    C   11.0   251.0  25.2  0.702  0.409  ...
# 10    2020-21  31.0  LAC  NBA    C    2.0    18.0  30.7  0.644  0.333  ...
# ...

# %%
df1[4]
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS      MP     FG     FGA  ...  \
# 0     2009-10  20.0  OKC  NBA   PF    6.0    0.0   153.0   20.0    35.0  ...
# 1     2010-11  21.0  OKC  NBA   PF   17.0   17.0   490.0   67.0   145.0  ...
# 2     2011-12  22.0  OKC  NBA   PF   20.0   20.0   569.0   84.0   159.0  ...
# 3     2012-13  23.0  OKC  NBA   PF   11.0   11.0   366.0   59.0   135.0  ...
# 4     2013-14  24.0  OKC  NBA   PF   17.0   17.0   581.0   87.0   147.0  ...
# 5     2015-16  26.0  OKC  NBA   PF   18.0   18.0   602.0   85.0   163.0  ...
# 6     2016-17  27.0  TOR  NBA   PF   10.0   10.0   307.0   60.0   130.0  ...
# 7     2017-18  28.0  TOR  NBA   PF   10.0    9.0   260.0   30.0    72.0  ...
# 8     2018-19  29.0  TOR  NBA    C   24.0    0.0   500.0   92.0   193.0  ...
# 9     2019-20  30.0  TOR  NBA    C   11.0    0.0   251.0   63.0   110.0  ...
# 10    2020-21  31.0  LAC  NBA    C    2.0    0.0    18.0    3.0     6.0  ...
# ...

# %%
for i in range(len(df1)):
    print(df1[i])
# Out:
#        Season   Age                                     Tm  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
df1[0]
# Out:
#        Season   Age                                     Tm  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
s ="""{
"name":"priya",
"marks":[20,23,4,5]
}""" 

# if i want to load data in differenetr differebt format

# %%
p ="""

{
"name":"priya",
"phone_no":2687368,
"comp":["priya","singh","janai","sano","pya","me"]}


"""

# %%
type(p)
# Out:
# str

# %%
import json  # json is javascript object notation
# json is simple key value kind  of data structure.

# %%
json.loads(s)
# Out:
# {'name': 'priya', 'marks': [20, 23, 4, 5]}

# %%
s1=json.loads(p)

# %%
s1
# Out:
# {'name': 'priya',
#  'phone_no': 2687368,
#  'comp': ['priya', 'singh', 'janai', 'sano', 'pya', 'me']}

# %%
pd.DataFrame(s1)
# Out:
#     name  phone_no   comp
# 0  priya   2687368  priya
# 1  priya   2687368  singh
# 2  priya   2687368  janai
# 3  priya   2687368   sano
# 4  priya   2687368    pya
# 5  priya   2687368     me

# %%
import requests

# %%
res=requests.get('https://api.github.com/repos/panadas-dev/pandas/issues')

# %%
res
# Out:
# <Response [404]>

# %%
js=res.json()

# %%
js
# Out:
# {'message': 'Not Found',
#  'documentation_url': 'https://docs.github.com/rest/issues/issues#list-repository-issues'}

# %%
json_data= """{
"name":"priya singh",
"number":"90896",
"marks":["10","34","34"]
}"""

# %%
type(json_data)
# Out:
# str

# %%
import json as j

# %%
json_data
# Out:
# '{\n"name":"priya singh",\n"number":"90896",\n"marks":["10","34","34"]\n}'

# %%
p=j.loads(json_data)

# %%
p
# Out:
# {'name': 'priya singh', 'number': '90896', 'marks': ['10', '34', '34']}

# %%
p["name"]
# Out:
# 'priya singh'

# %%
import pandas as pd

# %%
p1=pd.DataFrame(p)

# %%
p1
# Out:
#           name number marks
# 0  priya singh  90896    10
# 1  priya singh  90896    34
# 2  priya singh  90896    34

# %%
pd.DataFrame(p1,columns=["name","marks"])
# Out:
#           name marks
# 0  priya singh    10
# 1  priya singh    34
# 2  priya singh    34

# %%
import requests

# %%
t=requests.get("https://jsonplaceholder.typicode.com/todos/1")

# %%
t
# Out:
# <Response [200]>

# %%
t.json()
# Out:
# {'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}

# %%
import requests

# %%
p=requests.get('https://fakestoreapi.com/products')

# %%
p
# Out:
# <Response [200]>

# %%
df1=p.json()

# %%
 df1
# Out:
# [{'id': 1,
#   'title': 'Fjallraven - Foldsack No. 1 Backpack, Fits 15 Laptops',
#   'price': 109.95,
#   'description': 'Your perfect pack for everyday use and walks in the forest. Stash your laptop (up to 15 inches) in the padded sleeve, your everyday',
#   'category': "men's clothing",
#   'image': 'https://fakestoreapi.com/img/81fPKd-2AYL._AC_SL1500_.jpg',
#   'rating': {'rate': 3.9, 'count': 120}},
#  {'id': 2,
#   'title': 'Mens Casual Premium Slim Fit T-Shirts ',
#   'price': 22.3,
#   'description': 'Slim-fitting style, contrast raglan long sleeve, three-button henley placket, light weight & soft fabric for breathable and comfortable wearing. And Solid stitched shirts with round neck made for durability and a great fit for casual fashion wear and diehard baseball fans. The Henley style round neckline includes a three-button placket.',
#   'category': "men's clothing",
#   'image': 'https://fakestoreapi.com/img/71-3HjGNDUL._AC_SY879._SX._UX._SY._UY_.jpg',
# ...

# %%
df1[0]
# Out:
# {'id': 1,
#  'title': 'Fjallraven - Foldsack No. 1 Backpack, Fits 15 Laptops',
#  'price': 109.95,
#  'description': 'Your perfect pack for everyday use and walks in the forest. Stash your laptop (up to 15 inches) in the padded sleeve, your everyday',
#  'category': "men's clothing",
#  'image': 'https://fakestoreapi.com/img/81fPKd-2AYL._AC_SL1500_.jpg',
#  'rating': {'rate': 3.9, 'count': 120}}

# %%
len(df1)
# Out:
# 20

# %%
for i in range(len(df1)):
    print(df1[i]['rating'])
# Out:
# {'rate': 3.9, 'count': 120}
# {'rate': 4.1, 'count': 259}
# {'rate': 4.7, 'count': 500}
# {'rate': 2.1, 'count': 430}
# {'rate': 4.6, 'count': 400}
# {'rate': 3.9, 'count': 70}
# {'rate': 3, 'count': 400}
# {'rate': 1.9, 'count': 100}
# {'rate': 3.3, 'count': 203}
# {'rate': 2.9, 'count': 470}
# {'rate': 4.8, 'count': 319}
# {'rate': 4.8, 'count': 400}
# {'rate': 2.9, 'count': 250}
# {'rate': 2.2, 'count': 140}
# {'rate': 2.6, 'count': 235}
# {'rate': 2.9, 'count': 340}
# {'rate': 3.8, 'count': 679}
# {'rate': 4.7, 'count': 130}
# {'rate': 4.5, 'count': 146}
# {'rate': 3.6, 'count': 145}

# %%
df2=pd.DataFrame(df1)

# %%
df2.to_csv("json_dump.csv")

# %%
df1[0]['id']
# Out:
# 1

# %%
df7=df1[0]['rating']

# %%
df2
# Out:
#     id                                              title   price  \
# 0    1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1    2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2    3                                 Mens Cotton Jacket   55.99
# 3    4                               Mens Casual Slim Fit   15.99
# 4    5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5    6                       Solid Gold Petite Micropave   168.00
# 6    7                         White Gold Plated Princess    9.99
# 7    8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8    9  WD 2TB Elements Portable External Hard Drive -...   64.00
# 9   10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
# 10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# ...

# %%
pd.DataFrame(df2)
# Out:
#     id                                              title   price  \
# 0    1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1    2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2    3                                 Mens Cotton Jacket   55.99
# 3    4                               Mens Casual Slim Fit   15.99
# 4    5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5    6                       Solid Gold Petite Micropave   168.00
# 6    7                         White Gold Plated Princess    9.99
# 7    8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8    9  WD 2TB Elements Portable External Hard Drive -...   64.00
# 9   10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
# 10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# ...

# %%
type(df7)
# Out:
# dict

# %%
l=[]
for i in range(len(df1)):
    l.append(df1[i]['rating'])

# %%
l
# Out:
# [{'rate': 3.9, 'count': 120},
#  {'rate': 4.1, 'count': 259},
#  {'rate': 4.7, 'count': 500},
#  {'rate': 2.1, 'count': 430},
#  {'rate': 4.6, 'count': 400},
#  {'rate': 3.9, 'count': 70},
#  {'rate': 3, 'count': 400},
#  {'rate': 1.9, 'count': 100},
#  {'rate': 3.3, 'count': 203},
#  {'rate': 2.9, 'count': 470},
#  {'rate': 4.8, 'count': 319},
#  {'rate': 4.8, 'count': 400},
#  {'rate': 2.9, 'count': 250},
#  {'rate': 2.2, 'count': 140},
#  {'rate': 2.6, 'count': 235},
#  {'rate': 2.9, 'count': 340},
#  {'rate': 3.8, 'count': 679},
#  {'rate': 4.7, 'count': 130},
#  {'rate': 4.5, 'count': 146},
#  {'rate': 3.6, 'count': 145}]

# %%
df6=pd.DataFrame(l)

# %%
df6
# Out:
#     rate  count
# 0    3.9    120
# 1    4.1    259
# 2    4.7    500
# 3    2.1    430
# 4    4.6    400
# 5    3.9     70
# 6    3.0    400
# 7    1.9    100
# 8    3.3    203
# 9    2.9    470
# 10   4.8    319
# 11   4.8    400
# 12   2.9    250
# 13   2.2    140
# 14   2.6    235
# 15   2.9    340
# 16   3.8    679
# 17   4.7    130
# 18   4.5    146
# 19   3.6    145
