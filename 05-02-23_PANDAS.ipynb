# %%
import pandas as pd

# %%
from_csvfile=pd.read_csv('json_dump.csv')

# %%
from_csvfile
# Out:
#     Unnamed: 0  id                                              title   price  \
# 0            0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1            1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2            2   3                                 Mens Cotton Jacket   55.99
# 3            3   4                               Mens Casual Slim Fit   15.99
# 4            4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5            5   6                       Solid Gold Petite Micropave   168.00
# 6            6   7                         White Gold Plated Princess    9.99
# 7            7   8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8            8   9  WD 2TB Elements Portable External Hard Drive -...   64.00
# 9            9  10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# ...

# %%
from_csvfile.to_html('change.html')

# %%
from_csvfile.to_pickle("mypickle")

# %%
pwd()
# Out:
# 'C:\\Users\\ps242'

# %%
pd.read_pickle("mypickle")
# Out:
#     Unnamed: 0  id                                              title   price  \
# 0            0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1            1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2            2   3                                 Mens Cotton Jacket   55.99
# 3            3   4                               Mens Casual Slim Fit   15.99
# 4            4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5            5   6                       Solid Gold Petite Micropave   168.00
# 6            6   7                         White Gold Plated Princess    9.99
# 7            7   8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8            8   9  WD 2TB Elements Portable External Hard Drive -...   64.00
# 9            9  10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# ...

# %%
from_csvfile
# Out:
#     Unnamed: 0  id                                              title   price  \
# 0            0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1            1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2            2   3                                 Mens Cotton Jacket   55.99
# 3            3   4                               Mens Casual Slim Fit   15.99
# 4            4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5            5   6                       Solid Gold Petite Micropave   168.00
# 6            6   7                         White Gold Plated Princess    9.99
# 7            7   8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8            8   9  WD 2TB Elements Portable External Hard Drive -...   64.00
# 9            9  10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# ...

# %%
store_h5format=pd.HDFStore('store_h5format.h5')

# %%
store_h5format['obj1']=from_csvfile

# %%
df9=store_h5format['obj1']

# %%
store_h5format.select('obj2',where=['index >= 10 and index <= 15'])
# Out:
#     Unnamed: 0  id                                              title   price  \
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11          11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12          12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 13          13  14  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
# 14          14  15  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...   56.99
# 15          15  16  Lock and Love Women's Removable Hooded Faux Le...   29.95
#
#                                           description          category  \
# 10  3D NAND flash are applied to deliver high tran...       electronics
# 11  Expand your PS4 gaming experience, Play anywhe...       electronics
# 12  21. 5 inches Full HD (1920 x 1080) widescreen ...       electronics
# 13  49 INCH SUPER ULTRAWIDE 32:9 CURVED GAMING MON...       electronics
# ...

# %%
store_h5format.put('obj2',from_csvfile,format='table')

# %%
df10=store_h5format.select('obj2',where=['index >=10'])

# %%
store_h5format['obj2']

# %%
pd.read_hdf("store_h5format.h5")

# %%
df10=store_h5format.get('obj2')

# %%
df10.to_csv('h5_to_csv.csv')

# %%
pd.read_csv('h5_to_csv.csv')
# Out:
#    Unnamed: 0.1  Unnamed: 0  id  \
# 0            10          10  11
# 1            11          11  12
# 2            12          12  13
# 3            13          13  14
# 4            14          14  15
# 5            15          15  16
# 6            16          16  17
# 7            17          17  18
# 8            18          18  19
# 9            19          19  20
#
#                                                title   price  \
# 0  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 1  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 2  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 3  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
# 4  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...   56.99
# 5  Lock and Love Women's Removable Hooded Faux Le...   29.95
# 6  Rain Jacket Women Windbreaker Striped Climbing...   39.99
# 7        MBJ Women's Solid Short Sleeve Boat Neck V     9.85
# ...

# %%
df10
# Out:
#     Unnamed: 0  id                                              title   price  \
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11          11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12          12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 13          13  14  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
# 14          14  15  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...   56.99
# 15          15  16  Lock and Love Women's Removable Hooded Faux Le...   29.95
# 16          16  17  Rain Jacket Women Windbreaker Striped Climbing...   39.99
# 17          17  18        MBJ Women's Solid Short Sleeve Boat Neck V     9.85
# 18          18  19                 Opna Women's Short Sleeve Moisture    7.95
# 19          19  20         DANVOUY Womens T Shirt Casual Cotton Short   12.99
#
#                                           description          category  \
# ...

# %% [markdown]
# #  Initial Data Maipulation Operation

# %%
df10
# Out:
#     Unnamed: 0  id                                              title   price  \
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11          11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12          12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 13          13  14  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
# 14          14  15  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...   56.99
# 15          15  16  Lock and Love Women's Removable Hooded Faux Le...   29.95
# 16          16  17  Rain Jacket Women Windbreaker Striped Climbing...   39.99
# 17          17  18        MBJ Women's Solid Short Sleeve Boat Neck V     9.85
# 18          18  19                 Opna Women's Short Sleeve Moisture    7.95
# 19          19  20         DANVOUY Womens T Shirt Casual Cotton Short   12.99
#
#                                           description          category  \
# ...

# %%
df10.head(10)
# Out:
#     Unnamed: 0  id                                              title   price  \
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11          11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12          12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 13          13  14  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
# 14          14  15  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...   56.99
# 15          15  16  Lock and Love Women's Removable Hooded Faux Le...   29.95
# 16          16  17  Rain Jacket Women Windbreaker Striped Climbing...   39.99
# 17          17  18        MBJ Women's Solid Short Sleeve Boat Neck V     9.85
# 18          18  19                 Opna Women's Short Sleeve Moisture    7.95
# 19          19  20         DANVOUY Womens T Shirt Casual Cotton Short   12.99
#
#                                           description          category  \
# ...

# %%
df9.head(10)
# Out:
#    Unnamed: 0  id                                              title   price  \
# 0           0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1           1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2           2   3                                 Mens Cotton Jacket   55.99
# 3           3   4                               Mens Casual Slim Fit   15.99
# 4           4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5           5   6                       Solid Gold Petite Micropave   168.00
# 6           6   7                         White Gold Plated Princess    9.99
# 7           7   8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8           8   9  WD 2TB Elements Portable External Hard Drive -...   64.00
# 9           9  10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
#
#                                          description        category  \
# ...

# %%
df9.dtypes
# Out:
# Unnamed: 0       int64
# id               int64
# title           object
# price          float64
# description     object
# category        object
# image           object
# rating          object
# dtype: object

# %%
df9.describe()
# Out:
#        Unnamed: 0        id       price
# count    20.00000  20.00000   20.000000
# mean      9.50000  10.50000  162.046000
# std       5.91608   5.91608  272.220532
# min       0.00000   1.00000    7.950000
# 25%       4.75000   5.75000   15.240000
# 50%       9.50000  10.50000   56.490000
# 75%      14.25000  15.25000  110.962500
# max      19.00000  20.00000  999.990000

# %%
df9.dtypes[df9.dtypes=='object']   #filter opetaion
# Out:
# title          object
# description    object
# category       object
# image          object
# rating         object
# dtype: object

# %%
type(df9.dtypes)
# Out:
# pandas.core.series.Series

# %%
df11=df9[df9.dtypes[df9.dtypes=='object'].index]

# %%
df11.describe()
# Out:
#                                                     title  \
# count                                                  20
# unique                                                 20
# top     Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...
# freq                                                    1
#
#                                               description     category  \
# count                                                  20           20
# unique                                                 20            4
# top     Your perfect pack for everyday use and walks i...  electronics
# freq                                                    1            6
#
#                                                     image  \
# count                                                  20
# unique                                                 20
# top     https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...
# freq                                                    1
#
# ...

# %%
df8=df9[df9.dtypes[df9.dtypes=='object'].index]

# %%
df8.describe()
# Out:
#                                                     title  \
# count                                                  20
# unique                                                 20
# top     Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...
# freq                                                    1
#
#                                               description     category  \
# count                                                  20           20
# unique                                                 20            4
# top     Your perfect pack for everyday use and walks i...  electronics
# freq                                                    1            6
#
#                                                     image  \
# count                                                  20
# unique                                                 20
# top     https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...
# freq                                                    1
#
# ...

# %%
df11
# Out:
#                                                 title  \
# 0   Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...
# 1              Mens Casual Premium Slim Fit T-Shirts
# 2                                  Mens Cotton Jacket
# 3                                Mens Casual Slim Fit
# 4   John Hardy Women's Legends Naga Gold & Silver ...
# 5                        Solid Gold Petite Micropave
# 6                          White Gold Plated Princess
# 7   Pierced Owl Rose Gold Plated Stainless Steel D...
# 8   WD 2TB Elements Portable External Hard Drive -...
# 9   SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...
# 10  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...
# 11  WD 4TB Gaming Drive Works with Playstation 4 P...
# 12  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...
# 13  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...
# 14  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...
# 15  Lock and Love Women's Removable Hooded Faux Le...
# ...

# %%
df10
# Out:
#     Unnamed: 0  id                                              title   price  \
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11          11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12          12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 13          13  14  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
# 14          14  15  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...   56.99
# 15          15  16  Lock and Love Women's Removable Hooded Faux Le...   29.95
# 16          16  17  Rain Jacket Women Windbreaker Striped Climbing...   39.99
# 17          17  18        MBJ Women's Solid Short Sleeve Boat Neck V     9.85
# 18          18  19                 Opna Women's Short Sleeve Moisture    7.95
# 19          19  20         DANVOUY Womens T Shirt Casual Cotton Short   12.99
#
#                                           description          category  \
# ...

# %%
df10.describe()
# Out:
#        Unnamed: 0        id       price
# count    10.00000  10.00000   10.000000
# mean     14.50000  15.50000  197.971000
# std       3.02765   3.02765  332.967442
# min      10.00000  11.00000    7.950000
# 25%      12.25000  13.25000   17.230000
# 50%      14.50000  15.50000   48.490000
# 75%      16.75000  17.75000  112.750000
# max      19.00000  20.00000  999.990000

# %%
df10[['title','description','category']].describe()
# Out:
#                                                     title  \
# count                                                  10
# unique                                                 10
# top     Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...
# freq                                                    1
#
#                                               description          category
# count                                                  10                10
# unique                                                 10                 2
# top     3D NAND flash are applied to deliver high tran...  women's clothing
# freq                                                    1                 6

# %%
df10[['title']][11:19:2]
# Out:
# Empty DataFrame
# Columns: [title]
# Index: []

# %%
df10[df10.dtypes[df10.dtypes=='float64'].index]
# Out:
#      price
# 10  109.00
# 11  114.00
# 12  599.00
# 13  999.99
# 14   56.99
# 15   29.95
# 16   39.99
# 17    9.85
# 18    7.95
# 19   12.99

# %%
type(df10[['price']])
# Out:
# pandas.core.frame.DataFrame

# %%
l=[1,2,3,4,5,6,7,78,9]

# %%
l[6]
# Out:
# 7

# %%
df10[['price']]
# Out:
#      price
# 10  109.00
# 11  114.00
# 12  599.00
# 13  999.99
# 14   56.99
# 15   29.95
# 16   39.99
# 17    9.85
# 18    7.95
# 19   12.99

# %%
for i in df10.columns:
    print(df10[[i]])
# Out:
#     Unnamed: 0
# 10          10
# 11          11
# 12          12
# 13          13
# 14          14
# 15          15
# 16          16
# 17          17
# 18          18
# 19          19
#     id
# 10  11
# 11  12
# 12  13
# 13  14
# 14  15
# 15  16
# 16  17
# 17  18
# 18  19
# 19  20
#                                                 title
# 10  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...
# 11  WD 4TB Gaming Drive Works with Playstation 4 P...
# 12  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...
# 13  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...
# 14  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...
# 15  Lock and Love Women's Removable Hooded Faux Le...
# 16  Rain Jacket Women Windbreaker Striped Climbing...
# 17        MBJ Women's Solid Short Sleeve Boat Neck V
# 18                 Opna Women's Short Sleeve Moisture
# 19         DANVOUY Womens T Shirt Casual Cotton Short
#      price
# 10  109.00
# 11  114.00
# 12  599.00
# 13  999.99
# 14   56.99
# 15   29.95
# ...

# %%
df10.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'price', 'description', 'category',
#        'image', 'rating'],
#       dtype='object')

# %%
df10
# Out:
#     Unnamed: 0  id                                              title   price  \
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11          11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12          12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 13          13  14  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
# 14          14  15  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...   56.99
# 15          15  16  Lock and Love Women's Removable Hooded Faux Le...   29.95
# 16          16  17  Rain Jacket Women Windbreaker Striped Climbing...   39.99
# 17          17  18        MBJ Women's Solid Short Sleeve Boat Neck V     9.85
# 18          18  19                 Opna Women's Short Sleeve Moisture    7.95
# 19          19  20         DANVOUY Womens T Shirt Casual Cotton Short   12.99
#
#                                           description          category  \
# ...

# %%
df10['priya']='singh'

# %%
df10
# Out:
#     Unnamed: 0  id                                              title   price  \
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11          11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12          12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 13          13  14  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
# 14          14  15  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...   56.99
# 15          15  16  Lock and Love Women's Removable Hooded Faux Le...   29.95
# 16          16  17  Rain Jacket Women Windbreaker Striped Climbing...   39.99
# 17          17  18        MBJ Women's Solid Short Sleeve Boat Neck V     9.85
# 18          18  19                 Opna Women's Short Sleeve Moisture    7.95
# 19          19  20         DANVOUY Womens T Shirt Casual Cotton Short   12.99
#
#                                           description          category  \
# ...

# %%
df10
# Out:
#     Unnamed: 0  id                                              title   price  \
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11          11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12          12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 13          13  14  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
# 14          14  15  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...   56.99
# 15          15  16  Lock and Love Women's Removable Hooded Faux Le...   29.95
# 16          16  17  Rain Jacket Women Windbreaker Striped Climbing...   39.99
# 17          17  18        MBJ Women's Solid Short Sleeve Boat Neck V     9.85
# 18          18  19                 Opna Women's Short Sleeve Moisture    7.95
# 19          19  20         DANVOUY Womens T Shirt Casual Cotton Short   12.99
#
#                                           description          category  \
# ...

# %%
df11
# Out:
#                                                 title  \
# 0   Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...
# 1              Mens Casual Premium Slim Fit T-Shirts
# 2                                  Mens Cotton Jacket
# 3                                Mens Casual Slim Fit
# 4   John Hardy Women's Legends Naga Gold & Silver ...
# 5                        Solid Gold Petite Micropave
# 6                          White Gold Plated Princess
# 7   Pierced Owl Rose Gold Plated Stainless Steel D...
# 8   WD 2TB Elements Portable External Hard Drive -...
# 9   SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...
# 10  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...
# 11  WD 4TB Gaming Drive Works with Playstation 4 P...
# 12  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...
# 13  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...
# 14  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...
# 15  Lock and Love Women's Removable Hooded Faux Le...
# ...

# %%
df10['price']
# Out:
# 10    109.00
# 11    114.00
# 12    599.00
# 13    999.99
# 14     56.99
# 15     29.95
# 16     39.99
# 17      9.85
# 18      7.95
# 19     12.99
# Name: price, dtype: float64

# %% [markdown]
# #

# %%
df10
# Out:
#     Unnamed: 0  id                                              title   price  \
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11          11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12          12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 13          13  14  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
# 14          14  15  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...   56.99
# 15          15  16  Lock and Love Women's Removable Hooded Faux Le...   29.95
# 16          16  17  Rain Jacket Women Windbreaker Striped Climbing...   39.99
# 17          17  18        MBJ Women's Solid Short Sleeve Boat Neck V     9.85
# 18          18  19                 Opna Women's Short Sleeve Moisture    7.95
# 19          19  20         DANVOUY Womens T Shirt Casual Cotton Short   12.99
#
#                                           description          category  \
# ...

# %%
pd.Categorical(df10['category']).unique()
# Out:
# ['electronics', 'women's clothing']
# Categories (2, object): ['electronics', 'women's clothing']

# %%
df10
# Out:
#     Unnamed: 0  id                                              title   price  \
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11          11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12          12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 13          13  14  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
# 14          14  15  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...   56.99
# 15          15  16  Lock and Love Women's Removable Hooded Faux Le...   29.95
# 16          16  17  Rain Jacket Women Windbreaker Striped Climbing...   39.99
# 17          17  18        MBJ Women's Solid Short Sleeve Boat Neck V     9.85
# 18          18  19                 Opna Women's Short Sleeve Moisture    7.95
# 19          19  20         DANVOUY Womens T Shirt Casual Cotton Short   12.99
#
#                                           description          category  \
# ...

# %%
df10[df10['category']=='electronics']
# Out:
#     Unnamed: 0  id                                              title   price  \
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11          11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12          12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 13          13  14  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
#
#                                           description     category  \
# 10  3D NAND flash are applied to deliver high tran...  electronics
# 11  Expand your PS4 gaming experience, Play anywhe...  electronics
# 12  21. 5 inches Full HD (1920 x 1080) widescreen ...  electronics
# 13  49 INCH SUPER ULTRAWIDE 32:9 CURVED GAMING MON...  electronics
#
#                                                 image  \
# 10  https://fakestoreapi.com/img/71kWymZ+c+L._AC_S...
# 11  https://fakestoreapi.com/img/61mtL65D4cL._AC_S...
# 12  https://fakestoreapi.com/img/81QpkIctqPL._AC_S...
# ...

# %%
df10.iloc[[1,2,3]]
# Out:
#     Unnamed: 0  id                                              title   price  \
# 11          11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12          12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 13          13  14  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
#
#                                           description     category  \
# 11  Expand your PS4 gaming experience, Play anywhe...  electronics
# 12  21. 5 inches Full HD (1920 x 1080) widescreen ...  electronics
# 13  49 INCH SUPER ULTRAWIDE 32:9 CURVED GAMING MON...  electronics
#
#                                                 image  \
# 11  https://fakestoreapi.com/img/61mtL65D4cL._AC_S...
# 12  https://fakestoreapi.com/img/81QpkIctqPL._AC_S...
# 13  https://fakestoreapi.com/img/81Zt42ioCgL._AC_S...
#
#                          rating  priya
# 11  {'rate': 4.8, 'count': 400}  singh
# 12  {'rate': 2.9, 'count': 250}  singh
# 13  {'rate': 2.2, 'count': 140}  singh

# %%
df9
# Out:
#     Unnamed: 0  id                                              title   price  \
# 0            0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1            1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2            2   3                                 Mens Cotton Jacket   55.99
# 3            3   4                               Mens Casual Slim Fit   15.99
# 4            4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5            5   6                       Solid Gold Petite Micropave   168.00
# 6            6   7                         White Gold Plated Princess    9.99
# 7            7   8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8            8   9  WD 2TB Elements Portable External Hard Drive -...   64.00
# 9            9  10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# ...

# %% [markdown]
# # row with maximum fare name of title

# %%
df9[df9['price']==max(df9['price'])][['title']]
# Out:
#                                                 title
# 13  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...

# %%
import math

# %%
df9['id+price'] = str(df9['id'])+str(df9['price'])

# %%
df9
# Out:
#     Unnamed: 0  id                                              title   price  \
# 0            0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1            1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2            2   3                                 Mens Cotton Jacket   55.99
# 3            3   4                               Mens Casual Slim Fit   15.99
# 4            4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5            5   6                       Solid Gold Petite Micropave   168.00
# 6            6   7                         White Gold Plated Princess    9.99
# 7            7   8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8            8   9  WD 2TB Elements Portable External Hard Drive -...   64.00
# 9            9  10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
# 10          10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# ...

# %% [markdown]
# # Practise Assignment

# %%
import requests

# %%
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# ...

# %%
dataset1=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
dataset1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset1[dataset1['Embarked']=='S']['Sex'].count()
# Out:
# 644

# %%
dataset1[dataset1['Pclass']==max(dataset1['Pclass'])]['Name']
# Out:
# 0                       Braund, Mr. Owen Harris
# 2                        Heikkinen, Miss. Laina
# 4                      Allen, Mr. William Henry
# 5                              Moran, Mr. James
# 7                Palsson, Master. Gosta Leonard
#                          ...
# 882                Dahlberg, Miss. Gerda Ulrika
# 884                      Sutehall, Mr. Henry Jr
# 885        Rice, Mrs. William (Margaret Norton)
# 888    Johnston, Miss. Catherine Helen "Carrie"
# 890                         Dooley, Mr. Patrick
# Name: Name, Length: 491, dtype: object
